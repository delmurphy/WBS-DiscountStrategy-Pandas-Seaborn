# %% [markdown]
# # Cleaning Brands dataset

# %% [markdown]
# ### Read in data

# %%
import pandas as pd

# %%
path = '../data/data_raw/'
brands_orig = pd.read_csv(path + 'brands.csv')

# %%
brands = brands_orig.copy()

# %% [markdown]
# ### Check for duplicates

# %%
brands.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Eyeball the data

# %%
brands.sample(10)
# Out:
#     short              long
# 123   PHI           Philips
# 20    CAI          Casetify
# 12    BLL        BlueLounge
# 38    EVU            Evutec
# 7     APP             Apple
# 178   WIK           Wikango
# 13    BLM  Blue Microphones
# 126   POL          Polaroid
# 140   SAN           SanDisk
# 62    JAB             Jabra

# %%
brands.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   short   187 non-null    object
#  1   long    187 non-null    object
# dtypes: object(2)
# memory usage: 3.0+ KB

# %%
brands.isna().sum()
# Out:
# short    0
# long     0
# dtype: int64

# %% [markdown]
# All looks fine!
